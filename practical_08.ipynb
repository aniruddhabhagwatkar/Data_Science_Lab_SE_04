# %% [markdown]
# <a href="https://colab.research.google.com/github/aniruddhabhagwatkar/Data_Science_Lab_SE_04/blob/main/practical_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Load the ratings data
ratings_df = pd.read_csv('/content/rating.csv')

print("Ratings DataFrame head:")
display(ratings_df.head())
# Out:
# Ratings DataFrame head:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
# Load the movies data
movies_df = pd.read_csv('/content/movie.csv')

print("Movies DataFrame head:")
display(movies_df.head())
# Out:
# Movies DataFrame head:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Merge ratings and movies dataframes
merged_df = pd.merge(ratings_df, movies_df, on='movieId', how='left')

print("Merged DataFrame head:")
display(merged_df.head())
# Out:
# Merged DataFrame head:
#    userId  movieId  rating            timestamp  \
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40
#
#                                                title  \
# 0                                     Jumanji (1995)
# 1  City of Lost Children, The (Cité des enfants p...
# 2          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3                        Seven (a.k.a. Se7en) (1995)
# 4                         Usual Suspects, The (1995)
#
#                                    genres
# 0              Adventure|Children|Fantasy
# 1  Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 2                 Mystery|Sci-Fi|Thriller
# 3                        Mystery|Thriller
# 4                  Crime|Mystery|Thriller

# %%
# Merge datasets
df = pd.merge(ratings_df, movies_df, on='movieId')

df.head()
# Out:
#    userId  movieId  rating            timestamp  \
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40
#
#                                                title  \
# 0                                     Jumanji (1995)
# 1  City of Lost Children, The (Cité des enfants p...
# 2          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3                        Seven (a.k.a. Se7en) (1995)
# 4                         Usual Suspects, The (1995)
#
#                                    genres
# 0              Adventure|Children|Fantasy
# 1  Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 2                 Mystery|Sci-Fi|Thriller
# 3                        Mystery|Thriller
# 4                  Crime|Mystery|Thriller

# %%
genre = "Action"

genre_df = df[df['genres'].str.contains(genre)]

genre_df.head()
# Out:
#     userId  movieId  rating            timestamp  \
# 5        1      112     3.5  2004-09-10 03:09:00
# 6        1      151     4.0  2004-09-10 03:08:54
# 9        1      260     4.0  2005-04-02 23:33:46
# 10       1      293     4.0  2005-04-02 23:31:43
# 14       1      367     3.5  2005-04-02 23:53:00
#
#                                                 title  \
# 5          Rumble in the Bronx (Hont faan kui) (1995)
# 6                                      Rob Roy (1995)
# 9           Star Wars: Episode IV - A New Hope (1977)
# 10  Léon: The Professional (a.k.a. The Professiona...
# 14                                   Mask, The (1994)
#
#                            genres
# 5   Action|Adventure|Comedy|Crime
# 6        Action|Drama|Romance|War
# 9         Action|Adventure|Sci-Fi
# 10    Action|Crime|Drama|Thriller
# 14    Action|Comedy|Crime|Fantasy

# %%
avg_rating = genre_df['rating'].mean()
print(f"Average rating for {genre} movies:", avg_rating)
# Out:
# Average rating for Action movies: 3.44386376493354

# %%
# Take a smaller sample for faster processing
df_sample = df.sample(10000, random_state=42)

# Ensure genres column is clean
df_sample['genres'] = df_sample['genres'].fillna('').astype(str)

# Create dummy variables
genres_dummies = df_sample['genres'].str.get_dummies(sep='|')

# Combine with ratings
model_df = pd.concat([df_sample[['rating']], genres_dummies], axis=1)

model_df.head()
# Out:
#           rating  Action  Adventure  Animation  Children  Comedy  Crime  \
# 17679788     3.5       0          1          1         1       1      0
# 7106385      2.0       0          0          0         0       0      0
# 12970708     3.5       0          0          0         0       1      0
# 15426752     3.0       0          0          0         0       1      0
# 6934678      2.0       0          0          0         0       1      1
#
#           Documentary  Drama  Fantasy  Film-Noir  Horror  IMAX  Musical  \
# 17679788            0      0        0          0       0     0        1
# 7106385             0      0        0          0       0     0        0
# 12970708            0      1        0          0       0     0        0
# 15426752            0      1        0          0       0     0        0
# 6934678             0      0        0          0       0     0        0
#
#           Mystery  Romance  Sci-Fi  Thriller  War  Western
# 17679788        0        1       0         0    0        0
# 7106385         1        0       1         1    0        0
# 12970708        0        0       0         0    0        0
# 15426752        0        0       0         0    0        0
# 6934678         0        0       0         0    0        0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = model_df.drop('rating', axis=1)
y = model_df['rating']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Create input for prediction
input_data = pd.DataFrame([{
    col: 1 if col == "Action" else 0 for col in X.columns
}])

predicted_rating = model.predict(input_data)

print("Predicted Rating for Action movie:", predicted_rating[0])
# Out:
# Predicted Rating for Action movie: 3.2947850741623648

# %%
from sklearn.metrics import mean_squared_error

y_pred = model.predict(X_test)
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# MSE: 1.0399101067686096
